# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.linspace(0,200,1000)

# %%
x_coordinates = [0, 200]
y_coordinates = [1.10, 1.10]
y_coordinates1 = [1.28, 1.28]

plt.figure(figsize=(8,8))
plt.plot(x_coordinates, y_coordinates,'b',label='OS/LS 2016')
plt.plot(x_coordinates, y_coordinates1,'r',label='OS/LS 2017')
plt.xlim(0,200)
plt.ylim(1.0,1.4)
plt.xticks()
plt.grid()
plt.legend(fontsize=15)
plt.xlabel( r'm$_{rec}$(e, $\tau$, $\Delta$ P$_T$)[GeV]',fontsize=18,position=(0.80,2000))
plt.ylabel('OS/LS',fontsize=18,position=(2000,0.95))
plt.savefig('OS_LSTo.pdf',format='pdf')
plt.show()
